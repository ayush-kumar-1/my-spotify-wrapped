# %%
import pandas as pd 
import json
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt 
import matplotlib.patches as mpatches
from matplotlib.patches import FancyBboxPatch
from matplotlib.font_manager import FontProperties
from pywaffle import Waffle

import spotify_utils

# %%
spotify_utils.streaming_data()
# Out:
#                  endTime                   artistName  \
# 268  2021-01-01 03:08:00                   Chris King
# 269  2021-01-01 03:16:00                Playboi Carti
# 270  2021-01-01 03:47:00                     100 gecs
# 271  2021-01-01 03:49:00                     100 gecs
# 272  2021-01-01 03:50:00                   Little Big
# ...                  ...                          ...
# 2164 2021-12-17 18:33:00                 Taylor Swift
# 2165 2021-12-17 20:38:00                       Cortex
# 2166 2021-12-17 20:39:00                       Cortex
# 2167 2021-12-17 20:53:00  DJ Vibe Inc. & Max Barbaria
# 2168 2021-12-17 20:53:00                       Cortex
#
#                                               trackName  msPlayed
# 268                   Evil Kunevil (feat. Trippie Redd)     14762
# 269                                                Over       426
# 270   stupid horse (Remix) [feat. GFOTY & Count Baldor]     41122
# 271   hand crushed by a mallet (Remix) [feat. Fall O...    103886
# 272                                         Hypnodancer     57446
# ...                                                 ...       ...
# 2164                                            closure    180653
# 2165                            123: 2022 Yearly Themes   6814770
# 2166                                 88: Cortex Airport     82503
# 2167                                              Intro      6176
# 2168                  89: Everything is Constant Always    799651
#
# [11901 rows x 4 columns]
